# %% [markdown]
# ## Corelation between Life Expectancy & Gross Domestic Product (GDP)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
data = pd.read_csv("Life_Expectancy_Data.csv")

# %%
#Filter the DataFrame to only keep the countries from 'Africa' region
years_to_include = ['2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', ]

# Filter the DataFrame based on the regions in regions_to_include
africa_df = datafile_df[datafile_df['Region'].isin(regions_to_include)]

# Display the first few rows of the filtered DataFrame
africa_df.head()

# %%
#converting mortality to Average_mortality and adding it to Avg_Life_Expectancy
data["Average_mortality"] = data["Adult Mortality"].mean()
data["Avg_Life_Expertancy_Mortality"] = data["Average_mortality"] + data.iloc[:,3]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1649 entries, 0 to 1648
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          1649 non-null   object
#  1   Year                             1649 non-null   int64
#  2   Status                           1649 non-null   object
#  3   Life expectancy                  1649 non-null   float64
#  4   Adult Mortality                  1649 non-null   int64
#  5   infant deaths                    1649 non-null   int64
#  6   Alcohol                          1649 non-null   float64
#  7   percentage expenditure           1649 non-null   float64
#  8   Hepatitis B                      1649 non-null   int64
#  9   Measles                          1649 non-null   int64
#  10   BMI                             1649 non-null   float64
#  11  under-five deaths                1649 non-null   int64
# ...

# %%
#plot scatter plot to show corelation between life expectancy and population
x = data.iloc[:,23]
y = data.iloc[:,17]
fig, ax = plt.subplots()
ax.scatter(x, y)
plt.ylabel("Avg. Life Expectancy & Mortality")
plt.xlabel("Population")
plt.title("Life Expectancy & Population Correlation")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data1 = data.iloc[:,[23,17]]
correlation_matrix = data1.corr()
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Life Expectancy & Population Correlation")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The above images show that there is a weak negative correlation between average life expectancy & mortality and population in the dataset. This means that when life expectancy increases, population tends to decrease, but in a weak or unreliable manner.

# %%
#plot scatter plot to show corelation between life expectancy and GDP
x = data.iloc[:,23]
y = data.iloc[:,16]
fig, ax = plt.subplots()
ax.scatter(x, y)
plt.ylabel("Avg. Life Expectancy & Mortality")
plt.xlabel("GDP")
plt.title("Life Expectancy & GDP Correlation")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data1 = data.iloc[:,[23,16]]
correlation_matrix = data1.corr()
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Life Expectancy & GDP Correlation")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The above images show that there is a weak positive correlation between average life expectancy & mortality and population in the dataset. This means that although both life expectancy and GDP tend to go up in response to one another, the relationship is not very strong.

# %%
#calculate GDP per capita
data["GDP_per_capita"] = data["GDP"] / data.iloc[:,17]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1649 entries, 0 to 1648
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          1649 non-null   object
#  1   Year                             1649 non-null   int64
#  2   Status                           1649 non-null   object
#  3   Life expectancy                  1649 non-null   float64
#  4   Adult Mortality                  1649 non-null   int64
#  5   infant deaths                    1649 non-null   int64
#  6   Alcohol                          1649 non-null   float64
#  7   percentage expenditure           1649 non-null   float64
#  8   Hepatitis B                      1649 non-null   int64
#  9   Measles                          1649 non-null   int64
#  10   BMI                             1649 non-null   float64
#  11  under-five deaths                1649 non-null   int64
# ...

# %%
#plot scatter plot to show corelation between life expectancy and GDP
x = data.iloc[:,23]
y = data.iloc[:,24]
fig, ax = plt.subplots()
ax.scatter(x, y)
plt.ylabel("Avg. Life Expectancy & Mortality")
plt.xlabel("GDP Per Capita")
plt.title("Relationship between Life Expectancy & Mortality and GDP per capita")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data1 = data.iloc[:,[23,24]]
correlation_matrix = data1.corr()
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Relationship between Life Expectancy & Mortality and GDP per capita")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The above images show that there is a weak positive correlation between average life expectancy & mortality and population in the dataset. This means that although both life expectancy and GDP per capita tend to go up in response to one another, the relationship is not very strong.
